# %%
# Import needed libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import auto theft dataset
Police = pd.read_csv('./Basic_Methods-(Data)/Lab2/Auto_Theft_2014_to_2019.csv',encoding = 'unicode_escape')

# %%
# Check to see how many rows & columns
# Check to see data types
Police.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23380 entries, 0 to 23379
# Data columns (total 29 columns):
# X                      23380 non-null float64
# Y                      23380 non-null float64
# Index_                 23380 non-null int64
# event_unique_id        23380 non-null object
# occurrencedate         23380 non-null object
# reporteddate           23380 non-null object
# premisetype            23380 non-null object
# ucr_code               23380 non-null int64
# ucr_ext                23380 non-null int64
# offence                23380 non-null object
# reportedyear           23380 non-null int64
# reportedmonth          23380 non-null object
# reportedday            23380 non-null int64
# reporteddayofyear      23380 non-null int64
# reporteddayofweek      23380 non-null object
# reportedhour           23380 non-null int64
# occurrenceyear         23377 non-null float64
# occurrencemonth        23377 non-null object
# occurrenceday          23377 non-null float64
# occurrencedayofyear    23377 non-null float64
# occurrencedayofweek    23377 non-null object
# occurrencehour         23380 non-null int64
# MCI                    23380 non-null object
# Division               23380 non-null object
# Hood_ID                23380 non-null int64
# Neighbourhood          23380 non-null object
# Lat                    23380 non-null float64
# Long                   23380 non-null float64
# ObjectId               23380 non-null int64
# dtypes: float64(7), int64(10), object(12)
# memory usage: 5.2+ MB

# %%
# Check to see data descriptive statistics
Police.describe()
# Out:
#                   X             Y         Index_  ucr_code  ucr_ext  \
# count  2.338000e+04  2.338000e+04   23380.000000   23380.0  23380.0
# mean  -8.842468e+06  5.421871e+06  139836.194696    2135.0    210.0
# std    1.287636e+04  7.911834e+03   58722.388374       0.0      0.0
# min   -8.865373e+06  5.401805e+06   57370.000000    2135.0    210.0
# 25%   -8.853044e+06  5.415802e+06   63214.750000    2135.0    210.0
# 50%   -8.843666e+06  5.422107e+06  129399.500000    2135.0    210.0
# 75%   -8.832756e+06  5.427931e+06  200590.250000    2135.0    210.0
# max   -8.808155e+06  5.442380e+06  206435.000000    2135.0    210.0
#
#        reportedyear   reportedday  reporteddayofyear  reportedhour  \
# count  23380.000000  23380.000000       23380.000000  23380.000000
# mean    2016.785329     15.639179         191.357314     11.632849
# std        1.752191      8.709075         103.619117      5.557112
# min     2014.000000      1.000000           1.000000      0.000000
# 25%     2015.000000      8.000000         102.000000      8.000000
# 50%     2017.000000     16.000000         197.000000     11.000000
# 75%     2018.000000     23.000000         283.000000     16.000000
# max     2019.000000     31.000000         366.000000     23.000000
#
#        occurrenceyear  occurrenceday  occurrencedayofyear  occurrencehour  \
# count    23377.000000   23377.000000         23377.000000    23380.000000
# mean      2016.769731      15.606750           190.598409       14.170616
# std          1.772063       8.776699           103.556662        7.357208
# min       2000.000000       1.000000             1.000000        0.000000
# 25%       2015.000000       8.000000           102.000000        9.000000
# 50%       2017.000000      16.000000           195.000000       17.000000
# 75%       2018.000000      23.000000           282.000000       20.000000
# max       2019.000000      31.000000           366.000000       23.000000
#
#             Hood_ID           Lat          Long      ObjectId
# count  23380.000000  23380.000000  23380.000000  23380.000000
# mean      58.762618     43.717755    -79.433239  11690.500000
# std       45.683707      0.051370      0.115670   6749.368983
# min        1.000000     43.587353    -79.639000      1.000000
# 25%       21.000000     43.678360    -79.528250   5845.750000
# 50%       46.000000     43.719307    -79.444000  11690.500000
# 75%      104.000000     43.757109    -79.346000  17535.250000
# max      140.000000     43.850788    -79.125000  23380.000000

# %%
# See how actual dataset looks
Police.head(5)
# Out:
#               X             Y  Index_ event_unique_id          occurrencedate  \
# 0 -8.858137e+06  5.428285e+06   58170  GO-20141673399  2014/03/09 05:00:00+00
# 1 -8.851792e+06  5.427584e+06   58171  GO-20142467943  2014/07/10 04:00:00+00
# 2 -8.848230e+06  5.428533e+06   58172  GO-20142693275  2014/07/17 04:00:00+00
# 3 -8.859473e+06  5.424140e+06   58173  GO-20142530993  2014/07/17 04:00:00+00
# 4 -8.841105e+06  5.412458e+06   58174  GO-20142520781  2014/07/17 04:00:00+00
#
#              reporteddate premisetype  ucr_code  ucr_ext  \
# 0  2014/03/10 04:00:00+00       House      2135      210
# 1  2014/07/10 04:00:00+00     Outside      2135      210
# 2  2014/08/13 04:00:00+00  Commercial      2135      210
# 3  2014/07/19 04:00:00+00     Outside      2135      210
# 4  2014/07/18 04:00:00+00     Outside      2135      210
#
#                   offence  ...  occurrencedayofyear occurrencedayofweek  \
# 0  Theft Of Motor Vehicle  ...                 68.0          Sunday
# 1  Theft Of Motor Vehicle  ...                191.0          Thursday
# 2  Theft Of Motor Vehicle  ...                198.0          Thursday
# 3  Theft Of Motor Vehicle  ...                198.0          Thursday
# 4  Theft Of Motor Vehicle  ...                198.0          Thursday
#
#    occurrencehour         MCI Division  Hood_ID  \
# 0              17  Auto Theft      D31       21
# 1               9  Auto Theft      D31       25
# 2               0  Auto Theft      D31       27
# 3              21  Auto Theft      D23        2
# 4              18  Auto Theft      D14       80
#
#                            Neighbourhood        Lat    Long  ObjectId
# 0                     Humber Summit (21)  43.759407 -79.574         1
# 1            Glenfield-Jane Heights (25)  43.754856 -79.517         2
# 2           York University Heights (27)  43.761013 -79.485         3
# 3  Mount Olive-Silverstone-Jamestown (2)  43.732510 -79.586         4
# 4           Palmerston-Little Italy (80)  43.656632 -79.421         5
#
# [5 rows x 29 columns]

# %%
# Drop unecessary columns
Police.drop(['X','Y','Index_','event_unique_id','reporteddate','premisetype','ucr_ext','offence'], axis = 1, inplace = True)
Police.head(5)
# Out:
#            occurrencedate  ucr_code  reportedyear reportedmonth  reportedday  \
# 0  2014/03/09 05:00:00+00      2135          2014         March           10
# 1  2014/07/10 04:00:00+00      2135          2014          July           10
# 2  2014/07/17 04:00:00+00      2135          2014        August           13
# 3  2014/07/17 04:00:00+00      2135          2014          July           19
# 4  2014/07/17 04:00:00+00      2135          2014          July           18
#
#    reporteddayofyear reporteddayofweek  reportedhour  occurrenceyear  \
# 0                 69        Monday                 8          2014.0
# 1                191        Thursday               9          2014.0
# 2                225        Wednesday              9          2014.0
# 3                200        Saturday              19          2014.0
# 4                199        Friday                 8          2014.0
#
#   occurrencemonth  ...  occurrencedayofyear  occurrencedayofweek  \
# 0           March  ...                 68.0           Sunday
# 1            July  ...                191.0           Thursday
# 2            July  ...                198.0           Thursday
# 3            July  ...                198.0           Thursday
# 4            July  ...                198.0           Thursday
#
#   occurrencehour         MCI Division Hood_ID  \
# 0             17  Auto Theft      D31      21
# 1              9  Auto Theft      D31      25
# 2              0  Auto Theft      D31      27
# 3             21  Auto Theft      D23       2
# 4             18  Auto Theft      D14      80
#
#                            Neighbourhood        Lat    Long  ObjectId
# 0                     Humber Summit (21)  43.759407 -79.574         1
# 1            Glenfield-Jane Heights (25)  43.754856 -79.517         2
# 2           York University Heights (27)  43.761013 -79.485         3
# 3  Mount Olive-Silverstone-Jamestown (2)  43.732510 -79.586         4
# 4           Palmerston-Little Italy (80)  43.656632 -79.421         5
#
# [5 rows x 21 columns]

# %%
Police.drop(['ucr_code','reportedyear','reportedmonth','reporteddayofyear','reporteddayofweek'], axis = 1, inplace = True)
Police.head(5)
# Out:
#            occurrencedate  reportedday  reportedhour  occurrenceyear  \
# 0  2014/03/09 05:00:00+00           10             8          2014.0
# 1  2014/07/10 04:00:00+00           10             9          2014.0
# 2  2014/07/17 04:00:00+00           13             9          2014.0
# 3  2014/07/17 04:00:00+00           19            19          2014.0
# 4  2014/07/17 04:00:00+00           18             8          2014.0
#
#   occurrencemonth  occurrenceday  occurrencedayofyear occurrencedayofweek  \
# 0           March            9.0                 68.0          Sunday
# 1            July           10.0                191.0          Thursday
# 2            July           17.0                198.0          Thursday
# 3            July           17.0                198.0          Thursday
# 4            July           17.0                198.0          Thursday
#
#    occurrencehour         MCI Division  Hood_ID  \
# 0              17  Auto Theft      D31       21
# 1               9  Auto Theft      D31       25
# 2               0  Auto Theft      D31       27
# 3              21  Auto Theft      D23        2
# 4              18  Auto Theft      D14       80
#
#                            Neighbourhood        Lat    Long  ObjectId
# 0                     Humber Summit (21)  43.759407 -79.574         1
# 1            Glenfield-Jane Heights (25)  43.754856 -79.517         2
# 2           York University Heights (27)  43.761013 -79.485         3
# 3  Mount Olive-Silverstone-Jamestown (2)  43.732510 -79.586         4
# 4           Palmerston-Little Italy (80)  43.656632 -79.421         5

# %%
Police.drop(['reportedday','reportedhour','occurrencedate','occurrencedayofyear'], axis = 1, inplace = True)
Police.head(5)
# Out:
#    occurrenceyear occurrencemonth  occurrenceday occurrencedayofweek  \
# 0          2014.0           March            9.0          Sunday
# 1          2014.0            July           10.0          Thursday
# 2          2014.0            July           17.0          Thursday
# 3          2014.0            July           17.0          Thursday
# 4          2014.0            July           17.0          Thursday
#
#    occurrencehour         MCI Division  Hood_ID  \
# 0              17  Auto Theft      D31       21
# 1               9  Auto Theft      D31       25
# 2               0  Auto Theft      D31       27
# 3              21  Auto Theft      D23        2
# 4              18  Auto Theft      D14       80
#
#                            Neighbourhood        Lat    Long  ObjectId
# 0                     Humber Summit (21)  43.759407 -79.574         1
# 1            Glenfield-Jane Heights (25)  43.754856 -79.517         2
# 2           York University Heights (27)  43.761013 -79.485         3
# 3  Mount Olive-Silverstone-Jamestown (2)  43.732510 -79.586         4
# 4           Palmerston-Little Italy (80)  43.656632 -79.421         5

# %%
Police.drop(['MCI','Division','Hood_ID','Neighbourhood','Lat','Long','ObjectId'], axis = 1, inplace = True)
Police.head(5)
# Out:
#    occurrenceyear occurrencemonth  occurrenceday occurrencedayofweek  \
# 0          2014.0           March            9.0          Sunday
# 1          2014.0            July           10.0          Thursday
# 2          2014.0            July           17.0          Thursday
# 3          2014.0            July           17.0          Thursday
# 4          2014.0            July           17.0          Thursday
#
#    occurrencehour
# 0              17
# 1               9
# 2               0
# 3              21
# 4              18

# %%
# Check descriptive statistics for new dataset
Police.describe()
# Out:
#        occurrenceyear  occurrenceday  occurrencehour
# count    23377.000000   23377.000000    23380.000000
# mean      2016.769731      15.606750       14.170616
# std          1.772063       8.776699        7.357208
# min       2000.000000       1.000000        0.000000
# 25%       2015.000000       8.000000        9.000000
# 50%       2017.000000      16.000000       17.000000
# 75%       2018.000000      23.000000       20.000000
# max       2019.000000      31.000000       23.000000

# %%
# Change months to numerical data
Police['occurrencemonth'].replace({"July": 7}, inplace=True)
Police.head(5)
# Out:
#    occurrenceyear occurrencemonth  occurrenceday occurrencedayofweek  \
# 0          2014.0           March            9.0          Sunday
# 1          2014.0               7           10.0          Thursday
# 2          2014.0               7           17.0          Thursday
# 3          2014.0               7           17.0          Thursday
# 4          2014.0               7           17.0          Thursday
#
#    occurrencehour
# 0              17
# 1               9
# 2               0
# 3              21
# 4              18

# %%
Police['occurrencemonth'].replace({'January': 1,'February':2,'March':3,'April':4,'May':5 }, inplace=True)

# %%
Police['occurrencemonth'].replace({'June': 6,'August':8,'September':9,'October':10,'November':11,'December':12 }, inplace=True)
Police.head(10)
# Out:
#    occurrenceyear  occurrencemonth  occurrenceday occurrencedayofweek  \
# 0          2014.0              3.0            9.0          Sunday
# 1          2014.0              7.0           10.0          Thursday
# 2          2014.0              7.0           17.0          Thursday
# 3          2014.0              7.0           17.0          Thursday
# 4          2014.0              7.0           17.0          Thursday
# 5          2014.0              4.0           20.0          Sunday
# 6          2013.0             10.0            9.0          Wednesday
# 7          2013.0              9.0            1.0          Sunday
# 8          2014.0              7.0           17.0          Thursday
# 9          2014.0              4.0           20.0          Sunday
#
#    occurrencehour
# 0              17
# 1               9
# 2               0
# 3              21
# 4              18
# 5               1
# 6              12
# 7               9
# 8              18
# 9              21

# %%
# Change day of week to numerical data
# For some reason this line of code was not working
    # Could not figure out why
Police['occurrencedayofweek'].replace({'Thursday':4}, inplace=True)
Police.head(10)
# Out:
#    occurrenceyear  occurrencemonth  occurrenceday occurrencedayofweek  \
# 0          2014.0              3.0            9.0          Sunday
# 1          2014.0              7.0           10.0          Thursday
# 2          2014.0              7.0           17.0          Thursday
# 3          2014.0              7.0           17.0          Thursday
# 4          2014.0              7.0           17.0          Thursday
# 5          2014.0              4.0           20.0          Sunday
# 6          2013.0             10.0            9.0          Wednesday
# 7          2013.0              9.0            1.0          Sunday
# 8          2014.0              7.0           17.0          Thursday
# 9          2014.0              4.0           20.0          Sunday
#
#    occurrencehour
# 0              17
# 1               9
# 2               0
# 3              21
# 4              18
# 5               1
# 6              12
# 7               9
# 8              18
# 9              21

# %%
# Check to see if months have been successfully changed
Police['occurrencemonth'].value_counts()
# Out:
# 10.0    2279
# 11.0    2234
# 7.0     2091
# 8.0     2085
# 9.0     1992
# 6.0     1981
# 12.0    1908
# 5.0     1892
# 3.0     1868
# 4.0     1782
# 1.0     1713
# 2.0     1552
# Name: occurrencemonth, dtype: int64

# %%
# Check for null values
Police.isnull().sum()
# Out:
# occurrenceyear         3
# occurrencemonth        3
# occurrenceday          3
# occurrencedayofweek    3
# occurrencehour         0
# dtype: int64

# %%
# Check for zeros
Police[Police==0].count(axis=0, level=None, numeric_only=False)
# Out:
# occurrenceyear            0
# occurrencemonth           0
# occurrenceday             0
# occurrencedayofweek       0
# occurrencehour         1530
# dtype: int64

# %%
# large number of zeros in 'occurrencehour' just means auto theft happened
# at 24:00
Police['occurrencehour'].value_counts()
# Out:
# 22    2111
# 21    1885
# 23    1837
# 20    1718
# 0     1530
# 19    1508
# 18    1457
# 17    1179
# 12     998
# 16     947
# 1      748
# 15     730
# 14     705
# 8      689
# 9      685
# 7      658
# 10     631
# 13     617
# 2      573
# 11     533
# 6      460
# 3      436
# 5      383
# 4      362
# Name: occurrencehour, dtype: int64

# %%
# Check if there null values are consistent across rows
nan_values = Police[Police['occurrencedayofweek'].isna()]
print(nan_values)
# Out:
#       occurrenceyear  occurrencemonth  occurrenceday occurrencedayofweek  \
# 56               NaN              NaN            NaN                 NaN
# 6302             NaN              NaN            NaN                 NaN
# 6303             NaN              NaN            NaN                 NaN
#
#       occurrencehour
# 56                 0
# 6302               0
# 6303               0

# %%
# Drop null values
Police.dropna(subset = ['occurrencedayofweek'], inplace=True)

# %%
# No null values found
Police.isnull().sum()
# Out:
# occurrenceyear         0
# occurrencemonth        0
# occurrenceday          0
# occurrencedayofweek    0
# occurrencehour         0
# dtype: int64

# %%
#Police['occurrenceyear'] = pd.to_datetime(Police['occurrenceyear'])
#Police.set_index('occurrenceyear', inplace=True)

# %%
# Check for abnormalities in numbers
Police['occurrenceyear'].hist(figsize = (4,4))

# %%
# Chose to use last 5 years of data
Police['occurrenceyear'].value_counts()
# Out:
# 2019.0    5137
# 2018.0    4710
# 2017.0    3545
# 2014.0    3485
# 2016.0    3258
# 2015.0    3195
# 2013.0      32
# 2010.0       5
# 2008.0       3
# 2012.0       2
# 2000.0       2
# 2011.0       1
# 2009.0       1
# 2001.0       1
# Name: occurrenceyear, dtype: int64

# %%
# Chose to use last 5 years of data
Police_outlier = Police[Police['occurrenceyear'].isin([2015,2016,2017,2018,2019])]

# %%
Police_outlier['occurrenceyear'].value_counts()
# Out:
# 2019.0    5137
# 2018.0    4710
# 2017.0    3545
# 2016.0    3258
# 2015.0    3195
# Name: occurrenceyear, dtype: int64

# %%
Police_outlier['occurrenceyear'].sort_values(ascending = True)
# Out:
# 2017     2015.0
# 5642     2015.0
# 5643     2015.0
# 5644     2015.0
# 5645     2015.0
#           ...
# 19283    2019.0
# 19282    2019.0
# 19281    2019.0
# 19290    2019.0
# 23379    2019.0
# Name: occurrenceyear, Length: 19845, dtype: float64

# %%
Police_outlier
# Out:
#        occurrenceyear  occurrencemonth  occurrenceday occurrencedayofweek  \
# 2017           2015.0              1.0           29.0          Thursday
# 2106           2015.0              3.0           11.0          Wednesday
# 2107           2015.0              3.0           12.0          Thursday
# 2109           2015.0              3.0           12.0          Thursday
# 2115           2015.0              3.0           13.0          Friday
# ...               ...              ...            ...                 ...
# 23375          2019.0              8.0            6.0          Tuesday
# 23376          2019.0              8.0            6.0          Tuesday
# 23377          2019.0              8.0            6.0          Tuesday
# 23378          2019.0              8.0            7.0          Wednesday
# 23379          2019.0              8.0            7.0          Wednesday
#
#        occurrencehour
# 2017               22
# 2106               19
# 2107               18
# 2109               21
# 2115                6
# ...               ...
# 23375              17
# 23376               2
# 23377               4
# 23378              23
# 23379              22
#
# [19845 rows x 5 columns]

# %%
# Checking data
Police['occurrencemonth'].hist(figsize = (4,4))

# %%
# Checking data
Police['occurrenceday'].hist(figsize = (4,4))

# %%
# Checking data
Police['occurrencehour'].hist(figsize = (4,4))

# %%
dummy = pd.get_dummies(Police_outlier['occurrencedayofweek'])

# %%
# Created dummy variables for 'occurrencedayofweek' since i could not change to numerical value
dummy.head(5)
# Out:
#       Friday      Monday      Saturday    Sunday      Thursday    Tuesday     \
# 2017           0           0           0           0           1           0
# 2106           0           0           0           0           0           0
# 2107           0           0           0           0           1           0
# 2109           0           0           0           0           1           0
# 2115           1           0           0           0           0           0
#
#       Wednesday
# 2017           0
# 2106           1
# 2107           0
# 2109           0
# 2115           0

# %%
Police_outlier.head(5)
# Out:
#       occurrenceyear  occurrencemonth  occurrenceday occurrencedayofweek  \
# 2017          2015.0              1.0           29.0          Thursday
# 2106          2015.0              3.0           11.0          Wednesday
# 2107          2015.0              3.0           12.0          Thursday
# 2109          2015.0              3.0           12.0          Thursday
# 2115          2015.0              3.0           13.0          Friday
#
#       occurrencehour
# 2017              22
# 2106              19
# 2107              18
# 2109              21
# 2115               6

# %%
# Added two tables together
Police_concat = pd.concat([Police_outlier,dummy], axis = 1)

# %%
Police_concat
# Out:
#        occurrenceyear  occurrencemonth  occurrenceday occurrencedayofweek  \
# 2017           2015.0              1.0           29.0          Thursday
# 2106           2015.0              3.0           11.0          Wednesday
# 2107           2015.0              3.0           12.0          Thursday
# 2109           2015.0              3.0           12.0          Thursday
# 2115           2015.0              3.0           13.0          Friday
# ...               ...              ...            ...                 ...
# 23375          2019.0              8.0            6.0          Tuesday
# 23376          2019.0              8.0            6.0          Tuesday
# 23377          2019.0              8.0            6.0          Tuesday
# 23378          2019.0              8.0            7.0          Wednesday
# 23379          2019.0              8.0            7.0          Wednesday
#
#        occurrencehour  Friday      Monday      Saturday    Sunday      \
# 2017               22           0           0           0           0
# 2106               19           0           0           0           0
# 2107               18           0           0           0           0
# 2109               21           0           0           0           0
# 2115                6           1           0           0           0
# ...               ...         ...         ...         ...         ...
# 23375              17           0           0           0           0
# 23376               2           0           0           0           0
# 23377               4           0           0           0           0
# 23378              23           0           0           0           0
# 23379              22           0           0           0           0
#
#        Thursday    Tuesday     Wednesday
# 2017            1           0           0
# 2106            0           0           1
# 2107            1           0           0
# 2109            1           0           0
# 2115            0           0           0
# ...           ...         ...         ...
# 23375           0           1           0
# 23376           0           1           0
# 23377           0           1           0
# 23378           0           0           1
# 23379           0           0           1
#
# [19845 rows x 12 columns]

# %%
# Created column to count auto theft occurrences when next team member uses .groupby
# Will allow to group and count theft occurrences for different dates and times
Police_concat['occurr_count'] = 1

# %%
Police_concat
# Out:
#        occurrenceyear  occurrencemonth  occurrenceday occurrencedayofweek  \
# 2017           2015.0              1.0           29.0          Thursday
# 2106           2015.0              3.0           11.0          Wednesday
# 2107           2015.0              3.0           12.0          Thursday
# 2109           2015.0              3.0           12.0          Thursday
# 2115           2015.0              3.0           13.0          Friday
# ...               ...              ...            ...                 ...
# 23375          2019.0              8.0            6.0          Tuesday
# 23376          2019.0              8.0            6.0          Tuesday
# 23377          2019.0              8.0            6.0          Tuesday
# 23378          2019.0              8.0            7.0          Wednesday
# 23379          2019.0              8.0            7.0          Wednesday
#
#        occurrencehour  Friday      Monday      Saturday    Sunday      \
# 2017               22           0           0           0           0
# 2106               19           0           0           0           0
# 2107               18           0           0           0           0
# 2109               21           0           0           0           0
# 2115                6           1           0           0           0
# ...               ...         ...         ...         ...         ...
# 23375              17           0           0           0           0
# 23376               2           0           0           0           0
# 23377               4           0           0           0           0
# 23378              23           0           0           0           0
# 23379              22           0           0           0           0
#
#        Thursday    Tuesday     Wednesday   occurr_count
# 2017            1           0           0             1
# 2106            0           0           1             1
# 2107            1           0           0             1
# 2109            1           0           0             1
# 2115            0           0           0             1
# ...           ...         ...         ...           ...
# 23375           0           1           0             1
# 23376           0           1           0             1
# 23377           0           1           0             1
# 23378           0           0           1             1
# 23379           0           0           1             1
#
# [19845 rows x 13 columns]

# %%
#Police_concat.to_csv('DummyList.csv')

# %%
Police_outlier['occurr_count'] = 1
# Out:
# /Users/siddiqkhan/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
Police_outlier.head(5)
# Out:
#       occurrenceyear  occurrencemonth  occurrenceday occurrencedayofweek  \
# 2017          2015.0              1.0           29.0          Thursday
# 2106          2015.0              3.0           11.0          Wednesday
# 2107          2015.0              3.0           12.0          Thursday
# 2109          2015.0              3.0           12.0          Thursday
# 2115          2015.0              3.0           13.0          Friday
#
#       occurrencehour  occurr_count
# 2017              22             1
# 2106              19             1
# 2107              18             1
# 2109              21             1
# 2115               6             1

# %%
#Police_outlier.to_csv('No_DummyList.csv')
